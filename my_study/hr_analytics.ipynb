# %%
pip install opendatasets --upgrade --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import opendatasets as od

# %%
#dataset_url = 'https://www.kaggle.com/datasets/arashnic/hr-analytics-job-change-of-data-scientists'
#od.download(dataset_url)

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (2.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Чтение файлов

# %%
df=pd.read_csv(r'D:\vscode_files\python\notebooks\hr-analytics-job-change-of-data-scientists\aug_train.csv')

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target
# 0                  36     1.0
# 1                  47     0.0
# 2                  83     0.0
# 3                  52     1.0
# 4                   8     0.0
# ...               ...     ...
# 19153              42     1.0
# 19154              52     1.0
# 19155              44     0.0
# 19156              97     0.0
# 19157             127     0.0
#
# [19158 rows x 14 columns]

# %%
df.head(10)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
# 5        21651  city_176                   0.764    NaN
# 6        28806  city_160                   0.920   Male
# 7          402   city_46                   0.762   Male
# 8        27107  city_103                   0.920   Male
# 9          699  city_103                   0.920    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
# 5  Has relevent experience    Part time course        Graduate
# 6  Has relevent experience       no_enrollment     High School
# 7  Has relevent experience       no_enrollment        Graduate
# 8  Has relevent experience       no_enrollment        Graduate
# 9  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# 2             STEM          5          NaN             NaN        never
# 3  Business Degree         <1          NaN         Pvt Ltd        never
# 4             STEM        >20        50-99  Funded Startup            4
# 5             STEM         11          NaN             NaN            1
# 6              NaN          5        50-99  Funded Startup            1
# 7             STEM         13          <10         Pvt Ltd           >4
# 8             STEM          7        50-99         Pvt Ltd            1
# 9             STEM         17       10000+         Pvt Ltd           >4
#
#    training_hours  target
# 0              36     1.0
# 1              47     0.0
# 2              83     0.0
# 3              52     1.0
# 4               8     0.0
# 5              24     1.0
# 6              24     0.0
# 7              18     1.0
# 8              46     1.0
# 9             123     0.0

# %%
df.tail(10)
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 19148         9212   city_21                   0.624     NaN
# 19149          251  city_103                   0.920    Male
# 19150        32313  city_160                   0.920  Female
# 19151        11385  city_149                   0.689    Male
# 19152        29754  city_103                   0.920  Female
# 19153         7386  city_173                   0.878    Male
# 19154        31398  city_103                   0.920    Male
# 19155        24576  city_103                   0.920    Male
# 19156         5756   city_65                   0.802    Male
# 19157        23834   city_67                   0.855     NaN
#
#            relevent_experience enrolled_university education_level  \
# 19148  Has relevent experience       no_enrollment         Masters
# 19149  Has relevent experience       no_enrollment         Masters
# 19150  Has relevent experience       no_enrollment        Graduate
# 19151   No relevent experience    Full time course        Graduate
# 19152  Has relevent experience       no_enrollment        Graduate
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 19148             STEM          3      100-500         Pvt Ltd            3
# 19149             STEM          9        50-99         Pvt Ltd            1
# 19150             STEM         10      100-500   Public Sector            3
# 19151              NaN          2          NaN             NaN            1
# 19152       Humanities          7        10/49  Funded Startup            1
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target
# 19148              40     1.0
# 19149              36     1.0
# 19150              23     0.0
# 19151              60     0.0
# 19152              25     0.0
# 19153              42     1.0
# 19154              52     1.0
# 19155              44     0.0
# 19156              97     0.0
# 19157             127     0.0

# %%
df[['city','city_development_index']]
# двойные квадратные скобки выводят данные как табличные, одинарные(текстовые)
# Out:
#            city  city_development_index
# 0      city_103                   0.920
# 1       city_40                   0.776
# 2       city_21                   0.624
# 3      city_115                   0.789
# 4      city_162                   0.767
# ...         ...                     ...
# 19153  city_173                   0.878
# 19154  city_103                   0.920
# 19155  city_103                   0.920
# 19156   city_65                   0.802
# 19157   city_67                   0.855
#
# [19158 rows x 2 columns]

# %%
df['city']
# Out:
# 0        city_103
# 1         city_40
# 2         city_21
# 3        city_115
# 4        city_162
#            ...
# 19153    city_173
# 19154    city_103
# 19155    city_103
# 19156     city_65
# 19157     city_67
# Name: city, Length: 19158, dtype: object

# %%
len(df)
# Out:
# 19158

# %%
df.drop('city',axis=1)
# Out:
#        enrollee_id  city_development_index gender      relevent_experience  \
# 0             8949                   0.920   Male  Has relevent experience
# 1            29725                   0.776   Male   No relevent experience
# 2            11561                   0.624    NaN   No relevent experience
# 3            33241                   0.789    NaN   No relevent experience
# 4              666                   0.767   Male  Has relevent experience
# ...            ...                     ...    ...                      ...
# 19153         7386                   0.878   Male   No relevent experience
# 19154        31398                   0.920   Male  Has relevent experience
# 19155        24576                   0.920   Male  Has relevent experience
# 19156         5756                   0.802   Male  Has relevent experience
# 19157        23834                   0.855    NaN   No relevent experience
#
#       enrolled_university education_level major_discipline experience  \
# 0           no_enrollment        Graduate             STEM        >20
# 1           no_enrollment        Graduate             STEM         15
# 2        Full time course        Graduate             STEM          5
# 3                     NaN        Graduate  Business Degree         <1
# 4           no_enrollment         Masters             STEM        >20
# ...                   ...             ...              ...        ...
# 19153       no_enrollment        Graduate       Humanities         14
# 19154       no_enrollment        Graduate             STEM         14
# 19155       no_enrollment        Graduate             STEM        >20
# 19156       no_enrollment     High School              NaN         <1
# 19157       no_enrollment  Primary School              NaN          2
#
#       company_size    company_type last_new_job  training_hours  target
# 0              NaN             NaN            1              36     1.0
# 1            50-99         Pvt Ltd           >4              47     0.0
# 2              NaN             NaN        never              83     0.0
# 3              NaN         Pvt Ltd        never              52     1.0
# 4            50-99  Funded Startup            4               8     0.0
# ...            ...             ...          ...             ...     ...
# 19153          NaN             NaN            1              42     1.0
# 19154          NaN             NaN            4              52     1.0
# 19155        50-99         Pvt Ltd            4              44     0.0
# 19156      500-999         Pvt Ltd            2              97     0.0
# 19157          NaN             NaN            1             127     0.0
#
# [19158 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours', 'target'],
#       dtype='object')

# %%
df[['enrollee_id', 'city', 'city_development_index', 'gender',
       'relevent_experience', 'enrolled_university', 'education_level',
       'major_discipline', 'experience', 'company_size', 'company_type',
       'last_new_job', 'training_hours', 'target']]
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target
# 0                  36     1.0
# 1                  47     0.0
# 2                  83     0.0
# 3                  52     1.0
# 4                   8     0.0
# ...               ...     ...
# 19153              42     1.0
# 19154              52     1.0
# 19155              44     0.0
# 19156              97     0.0
# 19157             127     0.0
#
# [19158 rows x 14 columns]

# %%
df=pd.read_csv(r'D:\vscode_files\python\notebooks\hr-analytics-job-change-of-data-scientists\aug_train.csv')

# %%
df['new_call']=1

# %%
df['new_call2']=df['city_development_index']/3

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# 2             STEM          5          NaN             NaN        never
# 3  Business Degree         <1          NaN         Pvt Ltd        never
# 4             STEM        >20        50-99  Funded Startup            4
#
#    training_hours  target  new_call  new_call2
# 0              36     1.0         1   0.306667
# 1              47     0.0         1   0.258667
# 2              83     0.0         1   0.208000
# 3              52     1.0         1   0.263000
# 4               8     0.0         1   0.255667

# %%
df.assign(new_call3=99)
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target  new_call  new_call2  new_call3
# 0                  36     1.0         1   0.306667         99
# 1                  47     0.0         1   0.258667         99
# 2                  83     0.0         1   0.208000         99
# 3                  52     1.0         1   0.263000         99
# 4                   8     0.0         1   0.255667         99
# ...               ...     ...       ...        ...        ...
# 19153              42     1.0         1   0.292667         99
# 19154              52     1.0         1   0.306667         99
# 19155              44     0.0         1   0.306667         99
# 19156              97     0.0         1   0.267333         99
# 19157             127     0.0         1   0.285000         99
#
# [19158 rows x 17 columns]

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target  new_call  new_call2
# 0                  36     1.0         1   0.306667
# 1                  47     0.0         1   0.258667
# 2                  83     0.0         1   0.208000
# 3                  52     1.0         1   0.263000
# 4                   8     0.0         1   0.255667
# ...               ...     ...       ...        ...
# 19153              42     1.0         1   0.292667
# 19154              52     1.0         1   0.306667
# 19155              44     0.0         1   0.306667
# 19156              97     0.0         1   0.267333
# 19157             127     0.0         1   0.285000
#
# [19158 rows x 16 columns]

# %% [markdown]
# # Фильтрация и ворнинги

# %%
df[df['city'] =='city_40']
# Out:
#        enrollee_id     city  city_development_index gender  \
# 1            29725  city_40                   0.776   Male
# 23            7041  city_40                   0.776   Male
# 363          28229  city_40                   0.776   Male
# 461          18620  city_40                   0.776   Male
# 827           1783  city_40                   0.776   Male
# ...            ...      ...                     ...    ...
# 18032          982  city_40                   0.776    NaN
# 18061        11208  city_40                   0.776   Male
# 18191          157  city_40                   0.776   Male
# 18650        26348  city_40                   0.776   Male
# 19142        13750  city_40                   0.776   Male
#
#            relevent_experience enrolled_university education_level  \
# 1       No relevent experience       no_enrollment        Graduate
# 23     Has relevent experience       no_enrollment        Graduate
# 363    Has relevent experience    Part time course        Graduate
# 461    Has relevent experience    Full time course        Graduate
# 827    Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 18032   No relevent experience    Part time course        Graduate
# 18061   No relevent experience    Full time course        Graduate
# 18191  Has relevent experience    Full time course        Graduate
# 18650  Has relevent experience       no_enrollment     High School
# 19142  Has relevent experience       no_enrollment             NaN
#
#       major_discipline experience company_size         company_type  \
# 1                 STEM         15        50-99              Pvt Ltd
# 23          Humanities         <1    1000-4999              Pvt Ltd
# 363               STEM         18      100-500       Funded Startup
# 461               STEM         14    1000-4999              Pvt Ltd
# 827               STEM          7       10000+              Pvt Ltd
# ...                ...        ...          ...                  ...
# 18032             STEM          3          NaN                  NaN
# 18061             STEM         <1          NaN                  NaN
# 18191             STEM          5       10000+              Pvt Ltd
# 18650              NaN         13        50-99              Pvt Ltd
# 19142              NaN          5        10/49  Early Stage Startup
#
#       last_new_job  training_hours  target  new_call  new_call2
# 1               >4              47     0.0         1   0.258667
# 23               1              65     0.0         1   0.258667
# 363             >4              51     0.0         1   0.258667
# 461          never              52     0.0         1   0.258667
# 827              1              56     0.0         1   0.258667
# ...            ...             ...     ...       ...        ...
# 18032          NaN              34     1.0         1   0.258667
# 18061            1             127     1.0         1   0.258667
# 18191        never              42     0.0         1   0.258667
# 18650            1              10     0.0         1   0.258667
# 19142            1              26     0.0         1   0.258667
#
# [68 rows x 16 columns]

# %%
df.query('city == "city_40" and gender == "Male"')
# Out:
#        enrollee_id     city  city_development_index gender  \
# 1            29725  city_40                   0.776   Male
# 23            7041  city_40                   0.776   Male
# 363          28229  city_40                   0.776   Male
# 461          18620  city_40                   0.776   Male
# 827           1783  city_40                   0.776   Male
# 998          29671  city_40                   0.776   Male
# 2916         21646  city_40                   0.776   Male
# 3636         10085  city_40                   0.776   Male
# 4251          2603  city_40                   0.776   Male
# 4346          4051  city_40                   0.776   Male
# 4526         11840  city_40                   0.776   Male
# 4588          7010  city_40                   0.776   Male
# 5156          7556  city_40                   0.776   Male
# 6330          5389  city_40                   0.776   Male
# 6483           484  city_40                   0.776   Male
# 6990         14681  city_40                   0.776   Male
# 7009          1221  city_40                   0.776   Male
# 8606         10244  city_40                   0.776   Male
# 8661          3200  city_40                   0.776   Male
# 8847         27287  city_40                   0.776   Male
# 9390         33101  city_40                   0.776   Male
# 9658         17972  city_40                   0.776   Male
# 10952        23316  city_40                   0.776   Male
# 11072        25420  city_40                   0.776   Male
# 11700        16999  city_40                   0.776   Male
# 12228        12801  city_40                   0.776   Male
# 12601         8663  city_40                   0.776   Male
# 12782        27144  city_40                   0.776   Male
# 13385         9845  city_40                   0.776   Male
# 13520        22956  city_40                   0.776   Male
# 14231         1047  city_40                   0.776   Male
# 14462         8565  city_40                   0.776   Male
# 15553        28032  city_40                   0.776   Male
# 16174        15617  city_40                   0.776   Male
# 17315        25444  city_40                   0.776   Male
# 17324        15257  city_40                   0.776   Male
# 17761        31883  city_40                   0.776   Male
# 17803        11634  city_40                   0.776   Male
# 17849        12243  city_40                   0.776   Male
# 18061        11208  city_40                   0.776   Male
# 18191          157  city_40                   0.776   Male
# 18650        26348  city_40                   0.776   Male
# 19142        13750  city_40                   0.776   Male
#
#            relevent_experience enrolled_university education_level  \
# 1       No relevent experience       no_enrollment        Graduate
# 23     Has relevent experience       no_enrollment        Graduate
# 363    Has relevent experience    Part time course        Graduate
# 461    Has relevent experience    Full time course        Graduate
# 827    Has relevent experience       no_enrollment         Masters
# 998     No relevent experience    Full time course        Graduate
# 2916    No relevent experience    Full time course     High School
# 3636   Has relevent experience    Full time course        Graduate
# 4251   Has relevent experience       no_enrollment     High School
# 4346   Has relevent experience       no_enrollment        Graduate
# 4526   Has relevent experience    Full time course        Graduate
# 4588   Has relevent experience       no_enrollment        Graduate
# 5156    No relevent experience    Full time course        Graduate
# 6330   Has relevent experience       no_enrollment     High School
# 6483    No relevent experience    Full time course     High School
# 6990   Has relevent experience       no_enrollment     High School
# 7009   Has relevent experience       no_enrollment         Masters
# 8606   Has relevent experience       no_enrollment        Graduate
# 8661   Has relevent experience       no_enrollment        Graduate
# 8847   Has relevent experience       no_enrollment         Masters
# 9390   Has relevent experience       no_enrollment        Graduate
# 9658   Has relevent experience       no_enrollment         Masters
# 10952  Has relevent experience       no_enrollment        Graduate
# 11072  Has relevent experience       no_enrollment        Graduate
# 11700  Has relevent experience       no_enrollment        Graduate
# 12228  Has relevent experience    Part time course        Graduate
# 12601  Has relevent experience    Part time course        Graduate
# 12782  Has relevent experience       no_enrollment        Graduate
# 13385  Has relevent experience       no_enrollment         Masters
# 13520  Has relevent experience                 NaN        Graduate
# 14231  Has relevent experience       no_enrollment     High School
# 14462  Has relevent experience       no_enrollment         Masters
# 15553  Has relevent experience       no_enrollment        Graduate
# 16174  Has relevent experience       no_enrollment        Graduate
# 17315  Has relevent experience       no_enrollment         Masters
# 17324  Has relevent experience       no_enrollment        Graduate
# 17761  Has relevent experience    Part time course        Graduate
# 17803  Has relevent experience       no_enrollment        Graduate
# 17849   No relevent experience    Full time course        Graduate
# 18061   No relevent experience    Full time course        Graduate
# 18191  Has relevent experience    Full time course        Graduate
# 18650  Has relevent experience       no_enrollment     High School
# 19142  Has relevent experience       no_enrollment             NaN
#
#       major_discipline experience company_size         company_type  \
# 1                 STEM         15        50-99              Pvt Ltd
# 23          Humanities         <1    1000-4999              Pvt Ltd
# 363               STEM         18      100-500       Funded Startup
# 461               STEM         14    1000-4999              Pvt Ltd
# 827               STEM          7       10000+              Pvt Ltd
# 998               STEM          9          NaN                  NaN
# 2916               NaN          5          NaN                  NaN
# 3636              STEM         10    1000-4999              Pvt Ltd
# 4251               NaN          3        50-99              Pvt Ltd
# 4346              STEM        >20    1000-4999              Pvt Ltd
# 4526              STEM          3        50-99              Pvt Ltd
# 4588              STEM          5          <10              Pvt Ltd
# 5156              STEM          5          NaN                  NaN
# 6330               NaN          1        10/49              Pvt Ltd
# 6483               NaN          3          NaN              Pvt Ltd
# 6990               NaN         16      100-500       Funded Startup
# 7009              STEM         10    1000-4999              Pvt Ltd
# 8606             Other          4          <10              Pvt Ltd
# 8661        Humanities        >20          NaN                  NaN
# 8847             Other         10          <10              Pvt Ltd
# 9390              STEM         10      500-999              Pvt Ltd
# 9658              STEM          6          <10              Pvt Ltd
# 10952             STEM        >20        10/49              Pvt Ltd
# 11072             STEM        >20          NaN                  NaN
# 11700         No Major          6          <10              Pvt Ltd
# 12228             STEM        >20      100-500        Public Sector
# 12601             STEM         10        10/49              Pvt Ltd
# 12782             STEM        >20          <10              Pvt Ltd
# 13385             STEM         15        50-99              Pvt Ltd
# 13520             STEM          5        50-99                  NaN
# 14231              NaN         19          NaN                  NaN
# 14462             STEM          7        50-99                  NaN
# 15553             STEM          4          NaN                  NaN
# 16174       Humanities         11        10/49              Pvt Ltd
# 17315             STEM         10      100-500              Pvt Ltd
# 17324             STEM        >20          NaN                  NaN
# 17761             STEM          5        50-99              Pvt Ltd
# 17803             STEM          4        10/49              Pvt Ltd
# 17849             STEM          7          NaN                  NaN
# 18061             STEM         <1          NaN                  NaN
# 18191             STEM          5       10000+              Pvt Ltd
# 18650              NaN         13        50-99              Pvt Ltd
# 19142              NaN          5        10/49  Early Stage Startup
#
#       last_new_job  training_hours  target  new_call  new_call2
# 1               >4              47     0.0         1   0.258667
# 23               1              65     0.0         1   0.258667
# 363             >4              51     0.0         1   0.258667
# 461          never              52     0.0         1   0.258667
# 827              1              56     0.0         1   0.258667
# 998              1              50     0.0         1   0.258667
# 2916         never              56     1.0         1   0.258667
# 3636             1             104     0.0         1   0.258667
# 4251             1              28     0.0         1   0.258667
# 4346            >4              20     0.0         1   0.258667
# 4526             1               9     0.0         1   0.258667
# 4588             1               4     0.0         1   0.258667
# 5156             1             330     0.0         1   0.258667
# 6330             1              89     0.0         1   0.258667
# 6483         never              22     0.0         1   0.258667
# 6990            >4              76     0.0         1   0.258667
# 7009             1              32     0.0         1   0.258667
# 8606             1             108     0.0         1   0.258667
# 8661             4              29     0.0         1   0.258667
# 8847             2              35     0.0         1   0.258667
# 9390            >4              32     0.0         1   0.258667
# 9658             2              54     0.0         1   0.258667
# 10952            1              15     0.0         1   0.258667
# 11072           >4              22     0.0         1   0.258667
# 11700            3             144     0.0         1   0.258667
# 12228           >4              89     0.0         1   0.258667
# 12601           >4              13     0.0         1   0.258667
# 12782            1              58     0.0         1   0.258667
# 13385           >4              78     0.0         1   0.258667
# 13520            1              98     0.0         1   0.258667
# 14231            1              72     0.0         1   0.258667
# 14462            1              25     1.0         1   0.258667
# 15553            2              89     1.0         1   0.258667
# 16174            2              50     0.0         1   0.258667
# 17315            1              22     0.0         1   0.258667
# 17324            4              90     0.0         1   0.258667
# 17761            3              98     0.0         1   0.258667
# 17803            1              61     0.0         1   0.258667
# 17849        never               1     0.0         1   0.258667
# 18061            1             127     1.0         1   0.258667
# 18191        never              42     0.0         1   0.258667
# 18650            1              10     0.0         1   0.258667
# 19142            1              26     0.0         1   0.258667

# %%
df[(df['city'] == 'city_40')&(df['gender'] == 'Male')]
# Out:
#        enrollee_id     city  city_development_index gender  \
# 1            29725  city_40                   0.776   Male
# 23            7041  city_40                   0.776   Male
# 363          28229  city_40                   0.776   Male
# 461          18620  city_40                   0.776   Male
# 827           1783  city_40                   0.776   Male
# 998          29671  city_40                   0.776   Male
# 2916         21646  city_40                   0.776   Male
# 3636         10085  city_40                   0.776   Male
# 4251          2603  city_40                   0.776   Male
# 4346          4051  city_40                   0.776   Male
# 4526         11840  city_40                   0.776   Male
# 4588          7010  city_40                   0.776   Male
# 5156          7556  city_40                   0.776   Male
# 6330          5389  city_40                   0.776   Male
# 6483           484  city_40                   0.776   Male
# 6990         14681  city_40                   0.776   Male
# 7009          1221  city_40                   0.776   Male
# 8606         10244  city_40                   0.776   Male
# 8661          3200  city_40                   0.776   Male
# 8847         27287  city_40                   0.776   Male
# 9390         33101  city_40                   0.776   Male
# 9658         17972  city_40                   0.776   Male
# 10952        23316  city_40                   0.776   Male
# 11072        25420  city_40                   0.776   Male
# 11700        16999  city_40                   0.776   Male
# 12228        12801  city_40                   0.776   Male
# 12601         8663  city_40                   0.776   Male
# 12782        27144  city_40                   0.776   Male
# 13385         9845  city_40                   0.776   Male
# 13520        22956  city_40                   0.776   Male
# 14231         1047  city_40                   0.776   Male
# 14462         8565  city_40                   0.776   Male
# 15553        28032  city_40                   0.776   Male
# 16174        15617  city_40                   0.776   Male
# 17315        25444  city_40                   0.776   Male
# 17324        15257  city_40                   0.776   Male
# 17761        31883  city_40                   0.776   Male
# 17803        11634  city_40                   0.776   Male
# 17849        12243  city_40                   0.776   Male
# 18061        11208  city_40                   0.776   Male
# 18191          157  city_40                   0.776   Male
# 18650        26348  city_40                   0.776   Male
# 19142        13750  city_40                   0.776   Male
#
#            relevent_experience enrolled_university education_level  \
# 1       No relevent experience       no_enrollment        Graduate
# 23     Has relevent experience       no_enrollment        Graduate
# 363    Has relevent experience    Part time course        Graduate
# 461    Has relevent experience    Full time course        Graduate
# 827    Has relevent experience       no_enrollment         Masters
# 998     No relevent experience    Full time course        Graduate
# 2916    No relevent experience    Full time course     High School
# 3636   Has relevent experience    Full time course        Graduate
# 4251   Has relevent experience       no_enrollment     High School
# 4346   Has relevent experience       no_enrollment        Graduate
# 4526   Has relevent experience    Full time course        Graduate
# 4588   Has relevent experience       no_enrollment        Graduate
# 5156    No relevent experience    Full time course        Graduate
# 6330   Has relevent experience       no_enrollment     High School
# 6483    No relevent experience    Full time course     High School
# 6990   Has relevent experience       no_enrollment     High School
# 7009   Has relevent experience       no_enrollment         Masters
# 8606   Has relevent experience       no_enrollment        Graduate
# 8661   Has relevent experience       no_enrollment        Graduate
# 8847   Has relevent experience       no_enrollment         Masters
# 9390   Has relevent experience       no_enrollment        Graduate
# 9658   Has relevent experience       no_enrollment         Masters
# 10952  Has relevent experience       no_enrollment        Graduate
# 11072  Has relevent experience       no_enrollment        Graduate
# 11700  Has relevent experience       no_enrollment        Graduate
# 12228  Has relevent experience    Part time course        Graduate
# 12601  Has relevent experience    Part time course        Graduate
# 12782  Has relevent experience       no_enrollment        Graduate
# 13385  Has relevent experience       no_enrollment         Masters
# 13520  Has relevent experience                 NaN        Graduate
# 14231  Has relevent experience       no_enrollment     High School
# 14462  Has relevent experience       no_enrollment         Masters
# 15553  Has relevent experience       no_enrollment        Graduate
# 16174  Has relevent experience       no_enrollment        Graduate
# 17315  Has relevent experience       no_enrollment         Masters
# 17324  Has relevent experience       no_enrollment        Graduate
# 17761  Has relevent experience    Part time course        Graduate
# 17803  Has relevent experience       no_enrollment        Graduate
# 17849   No relevent experience    Full time course        Graduate
# 18061   No relevent experience    Full time course        Graduate
# 18191  Has relevent experience    Full time course        Graduate
# 18650  Has relevent experience       no_enrollment     High School
# 19142  Has relevent experience       no_enrollment             NaN
#
#       major_discipline experience company_size         company_type  \
# 1                 STEM         15        50-99              Pvt Ltd
# 23          Humanities         <1    1000-4999              Pvt Ltd
# 363               STEM         18      100-500       Funded Startup
# 461               STEM         14    1000-4999              Pvt Ltd
# 827               STEM          7       10000+              Pvt Ltd
# 998               STEM          9          NaN                  NaN
# 2916               NaN          5          NaN                  NaN
# 3636              STEM         10    1000-4999              Pvt Ltd
# 4251               NaN          3        50-99              Pvt Ltd
# 4346              STEM        >20    1000-4999              Pvt Ltd
# 4526              STEM          3        50-99              Pvt Ltd
# 4588              STEM          5          <10              Pvt Ltd
# 5156              STEM          5          NaN                  NaN
# 6330               NaN          1        10/49              Pvt Ltd
# 6483               NaN          3          NaN              Pvt Ltd
# 6990               NaN         16      100-500       Funded Startup
# 7009              STEM         10    1000-4999              Pvt Ltd
# 8606             Other          4          <10              Pvt Ltd
# 8661        Humanities        >20          NaN                  NaN
# 8847             Other         10          <10              Pvt Ltd
# 9390              STEM         10      500-999              Pvt Ltd
# 9658              STEM          6          <10              Pvt Ltd
# 10952             STEM        >20        10/49              Pvt Ltd
# 11072             STEM        >20          NaN                  NaN
# 11700         No Major          6          <10              Pvt Ltd
# 12228             STEM        >20      100-500        Public Sector
# 12601             STEM         10        10/49              Pvt Ltd
# 12782             STEM        >20          <10              Pvt Ltd
# 13385             STEM         15        50-99              Pvt Ltd
# 13520             STEM          5        50-99                  NaN
# 14231              NaN         19          NaN                  NaN
# 14462             STEM          7        50-99                  NaN
# 15553             STEM          4          NaN                  NaN
# 16174       Humanities         11        10/49              Pvt Ltd
# 17315             STEM         10      100-500              Pvt Ltd
# 17324             STEM        >20          NaN                  NaN
# 17761             STEM          5        50-99              Pvt Ltd
# 17803             STEM          4        10/49              Pvt Ltd
# 17849             STEM          7          NaN                  NaN
# 18061             STEM         <1          NaN                  NaN
# 18191             STEM          5       10000+              Pvt Ltd
# 18650              NaN         13        50-99              Pvt Ltd
# 19142              NaN          5        10/49  Early Stage Startup
#
#       last_new_job  training_hours  target  new_call  new_call2
# 1               >4              47     0.0         1   0.258667
# 23               1              65     0.0         1   0.258667
# 363             >4              51     0.0         1   0.258667
# 461          never              52     0.0         1   0.258667
# 827              1              56     0.0         1   0.258667
# 998              1              50     0.0         1   0.258667
# 2916         never              56     1.0         1   0.258667
# 3636             1             104     0.0         1   0.258667
# 4251             1              28     0.0         1   0.258667
# 4346            >4              20     0.0         1   0.258667
# 4526             1               9     0.0         1   0.258667
# 4588             1               4     0.0         1   0.258667
# 5156             1             330     0.0         1   0.258667
# 6330             1              89     0.0         1   0.258667
# 6483         never              22     0.0         1   0.258667
# 6990            >4              76     0.0         1   0.258667
# 7009             1              32     0.0         1   0.258667
# 8606             1             108     0.0         1   0.258667
# 8661             4              29     0.0         1   0.258667
# 8847             2              35     0.0         1   0.258667
# 9390            >4              32     0.0         1   0.258667
# 9658             2              54     0.0         1   0.258667
# 10952            1              15     0.0         1   0.258667
# 11072           >4              22     0.0         1   0.258667
# 11700            3             144     0.0         1   0.258667
# 12228           >4              89     0.0         1   0.258667
# 12601           >4              13     0.0         1   0.258667
# 12782            1              58     0.0         1   0.258667
# 13385           >4              78     0.0         1   0.258667
# 13520            1              98     0.0         1   0.258667
# 14231            1              72     0.0         1   0.258667
# 14462            1              25     1.0         1   0.258667
# 15553            2              89     1.0         1   0.258667
# 16174            2              50     0.0         1   0.258667
# 17315            1              22     0.0         1   0.258667
# 17324            4              90     0.0         1   0.258667
# 17761            3              98     0.0         1   0.258667
# 17803            1              61     0.0         1   0.258667
# 17849        never               1     0.0         1   0.258667
# 18061            1             127     1.0         1   0.258667
# 18191        never              42     0.0         1   0.258667
# 18650            1              10     0.0         1   0.258667
# 19142            1              26     0.0         1   0.258667

# %%
city_40_male = df[(df['city'] == 'city_40')&(df['gender'] == 'Male')].copy()

# %%
city_40_male['new_call_3']=3

# %% [markdown]
# # Пропуски

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# company_type              0.320493
# company_size              0.309949
# gender                    0.235306
# major_discipline          0.146832
# education_level           0.024011
# last_new_job              0.022080
# enrolled_university       0.020148
# experience                0.003393
# relevent_experience       0.000000
# enrollee_id               0.000000
# city                      0.000000
# city_development_index    0.000000
# training_hours            0.000000
# target                    0.000000
# new_call                  0.000000
# new_call2                 0.000000
# dtype: float64

# %% [markdown]
# # Типы переменных

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target  new_call  new_call2
# 0                  36     1.0         1   0.306667
# 1                  47     0.0         1   0.258667
# 2                  83     0.0         1   0.208000
# 3                  52     1.0         1   0.263000
# 4                   8     0.0         1   0.255667
# ...               ...     ...       ...        ...
# 19153              42     1.0         1   0.292667
# 19154              52     1.0         1   0.306667
# 19155              44     0.0         1   0.306667
# 19156              97     0.0         1   0.267333
# 19157             127     0.0         1   0.285000
#
# [19158 rows x 16 columns]

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install ipympl
# Out:
# Requirement already satisfied: ipympl in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (0.9.4)
# Requirement already satisfied: ipython-genutils in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: ipython<9 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipympl) (8.28.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from ipympl) (8.1.5)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from ipympl) (3.9.2)
# Requirement already satisfied: numpy in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from ipympl) (2.1.2)
# Requirement already satisfied: pillow in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from ipympl) (10.4.0)
# Requirement already satisfied: traitlets<6 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: decorator in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (0.6.3)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (4.12.2)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib<4,>=3.4.0->ipympl) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\user\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\user\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from stack-data->ipython<9->ipympl) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from stack-data->ipython<9->ipympl) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\user\appdata\roaming\python\python311\site-packages (from stack-data->ipython<9->ipympl) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('dark_background')

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index  training_hours        target  \
# count  19158.000000            19158.000000    19158.000000  19158.000000
# mean   16875.358179                0.828848       65.366896      0.249348
# std     9616.292592                0.123362       60.058462      0.432647
# min        1.000000                0.448000        1.000000      0.000000
# 25%     8554.250000                0.740000       23.000000      0.000000
# 50%    16982.500000                0.903000       47.000000      0.000000
# 75%    25169.750000                0.920000       88.000000      0.000000
# max    33380.000000                0.949000      336.000000      1.000000
#
#        new_call     new_call2
# count   19158.0  19158.000000
# mean        1.0      0.276283
# std         0.0      0.041121
# min         1.0      0.149333
# 25%         1.0      0.246667
# 50%         1.0      0.301000
# 75%         1.0      0.306667
# max         1.0      0.316333

# %%
df['gender'].value_counts(dropna=False)
# Out:
# gender
# Male      13221
# NaN        4508
# Female     1238
# Other       191
# Name: count, dtype: int64

# %% [markdown]
# # Фильтрация по квантилю

# %%
q = df['city_development_index'].quantile(0.25)

# %%
df[df['city_development_index'] < q]
# Out:
#        enrollee_id      city  city_development_index gender  \
# 2            11561   city_21                   0.624    NaN
# 10           29452   city_21                   0.624    NaN
# 13            5826   city_21                   0.624   Male
# 14            8722   city_21                   0.624    NaN
# 17            5764   city_21                   0.624    NaN
# ...            ...       ...                     ...    ...
# 19144        17191   city_21                   0.624    NaN
# 19145          155   city_44                   0.725    NaN
# 19147        21319   city_21                   0.624   Male
# 19148         9212   city_21                   0.624    NaN
# 19151        11385  city_149                   0.689   Male
#
#            relevent_experience enrolled_university education_level  \
# 2       No relevent experience    Full time course        Graduate
# 10      No relevent experience    Full time course     High School
# 13      No relevent experience                 NaN             NaN
# 14      No relevent experience    Full time course     High School
# 17     Has relevent experience       no_enrollment        Graduate
# ...                        ...                 ...             ...
# 19144   No relevent experience    Full time course        Graduate
# 19145   No relevent experience    Full time course        Graduate
# 19147   No relevent experience    Full time course        Graduate
# 19148  Has relevent experience       no_enrollment         Masters
# 19151   No relevent experience    Full time course        Graduate
#
#       major_discipline experience company_size company_type last_new_job  \
# 2                 STEM          5          NaN          NaN        never
# 10                 NaN          2          NaN          NaN        never
# 13                 NaN          2          NaN          NaN        never
# 14                 NaN          5          NaN          NaN        never
# 17                STEM          2    5000-9999      Pvt Ltd            2
# ...                ...        ...          ...          ...          ...
# 19144             STEM          4          NaN          NaN        never
# 19145             STEM          5          NaN      Pvt Ltd        never
# 19147             STEM          1      100-500      Pvt Ltd            1
# 19148             STEM          3      100-500      Pvt Ltd            3
# 19151              NaN          2          NaN          NaN            1
#
#        training_hours  target  new_call  new_call2
# 2                  83     0.0         1   0.208000
# 10                 32     1.0         1   0.208000
# 13                 24     0.0         1   0.208000
# 14                 26     0.0         1   0.208000
# 17                  7     0.0         1   0.208000
# ...               ...     ...       ...        ...
# 19144              48     1.0         1   0.208000
# 19145             190     0.0         1   0.241667
# 19147              52     1.0         1   0.208000
# 19148              40     1.0         1   0.208000
# 19151              60     0.0         1   0.229667
#
# [4771 rows x 16 columns]

# %%
q1 = df['city_development_index'].quantile(0.05)
q2 = df['city_development_index'].quantile(0.95)

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
df[df['city_development_index'].between(q1,q2)]['city_development_index'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Сводники

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target  new_call  new_call2
# 0                  36     1.0         1   0.306667
# 1                  47     0.0         1   0.258667
# 2                  83     0.0         1   0.208000
# 3                  52     1.0         1   0.263000
# 4                   8     0.0         1   0.255667
# ...               ...     ...       ...        ...
# 19153              42     1.0         1   0.292667
# 19154              52     1.0         1   0.306667
# 19155              44     0.0         1   0.306667
# 19156              97     0.0         1   0.267333
# 19157             127     0.0         1   0.285000
#
# [19158 rows x 16 columns]

# %%
len(df)
# Out:
# 19158

# %%
df['target'].mean()
# Out:
# np.float64(0.24934753105752167)

# %%
t = df.groupby('gender', dropna=False)['target'].agg(['count','mean'])

# %%
t
# Out:
#         count      mean
# gender
# Female   1238  0.263328
# Male    13221  0.227819
# Other     191  0.261780
# NaN      4508  0.308119

# %%
t['count'].sum()
# Out:
# np.int64(19158)

# %%
df.groupby('education_level', dropna=False)['target'].agg(['count','mean'])
# dropna учитывает пропуски в таблицах, то есть не дропаем NaN(пропуски)
# Out:
#                  count      mean
# education_level
# Graduate         11598  0.279790
# High School       2017  0.195340
# Masters           4361  0.214400
# Phd                414  0.140097
# Primary School     308  0.133117
# NaN                460  0.226087

# %%
df.groupby('education_level', dropna=False)['target'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='education_level'>

# %% [markdown]
# # Сводники для непрерывных переменных

# %%
df['city_development_index_group'] = pd.cut(df['city_development_index'],5)
# делит city_development_index на 5 равных интервалов от минимума до максимума по city_development_index

# %%
df.groupby('city_development_index_group', dropna=False)['target'].agg(['count','mean'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_34732\2160038516.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('city_development_index_group', dropna=False)['target'].agg(['count','mean'])
#                               count      mean
# city_development_index_group
# (0.447, 0.548]                  178  0.578652
# (0.548, 0.648]                 3297  0.582651
# (0.648, 0.749]                 1529  0.273381
# (0.749, 0.849]                 1949  0.194459
# (0.849, 0.949]                12205  0.160262

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
df['city_development_index_group_q'] = pd.qcut(df['city_development_index'],5,duplicates='drop')
# делит city_development_index примерно на 5 равных интервалов по количеству при этом дубликаты удаляя

# %%
t = df.groupby('city_development_index_group_q', dropna=False)['target'].agg(['count','mean'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_34732\8683933.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   t = df.groupby('city_development_index_group_q', dropna=False)['target'].agg(['count','mean'])

# %%
t['count'].sum()
# Out:
# np.int64(19158)

# %%
t['count']
# Out:
# city_development_index_group_q
# (0.447, 0.691]    3869
# (0.691, 0.878]    3827
# (0.878, 0.92]     8925
# (0.92, 0.949]     2537
# Name: count, dtype: int64

# %%
t['mean'].plot()
# Out:
# <Axes: xlabel='city_development_index_group_q'>

# %%
df['city_development_index_group_custom'] = pd.cut(df['city_development_index'],
                                                   [-float('inf'),0.1,0.2,0.5,float('inf')])

# %%
df.groupby('city_development_index_group_custom', dropna=False)['target'].agg(['count','mean'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_34732\3550661946.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('city_development_index_group_custom', dropna=False)['target'].agg(['count','mean'])
#                                      count      mean
# city_development_index_group_custom
# (-inf, 0.1]                              0       NaN
# (0.1, 0.2]                               0       NaN
# (0.2, 0.5]                              63  0.587302
# (0.5, inf]                           19095  0.248233

# %% [markdown]
# # Группировка категориальных переменных

# %%
df.groupby('education_level', dropna=False)['target'].agg(['count','mean'])
# Out:
#                  count      mean
# education_level
# Graduate         11598  0.279790
# High School       2017  0.195340
# Masters           4361  0.214400
# Phd                414  0.140097
# Primary School     308  0.133117
# NaN                460  0.226087

# %%
def education_group(x):
    if x in ['High School', 'Primary School']:
        return 'School'
    if x in ['Masters', 'Phd']:
        return 'Masters_and_Phd'
    return x

# %%
df['new_education_level'] = df['education_level'].apply(education_group)

# %%
df.groupby('new_education_level', dropna=False)['target'].agg(['count','mean'])
# Out:
#                      count      mean
# new_education_level
# Graduate             11598  0.279790
# Masters_and_Phd       4775  0.207958
# School                2325  0.187097
# NaN                    460  0.226087

# %%
df['education_level'].replace('Primary School', 'School')
# Out:
# 0           Graduate
# 1           Graduate
# 2           Graduate
# 3           Graduate
# 4            Masters
#             ...
# 19153       Graduate
# 19154       Graduate
# 19155       Graduate
# 19156    High School
# 19157         School
# Name: education_level, Length: 19158, dtype: object

# %%
d = {'Primary School': 'School', 'High School': 'School' }

# %%
df['education_level'].map(d)
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 19153       NaN
# 19154       NaN
# 19155       NaN
# 19156    School
# 19157    School
# Name: education_level, Length: 19158, dtype: object

# %% [markdown]
# # Функция с несколькими столбцами

# %%
def new_training_hours(row):
    if row['education_level'] == 'Phd':
        return row['training_hours'] + 1000
    return row['training_hours']

# %%
df['new_training_hours'] = df.apply(new_training_hours, axis=1)

# %%
df[df['education_level'] == 'Phd']
# Out:
#        enrollee_id      city  city_development_index gender  \
# 37           10164  city_114                   0.926   Male
# 121          13915   city_16                   0.910   Male
# 130           3921   city_36                   0.893    NaN
# 135          23947  city_103                   0.920    NaN
# 152          31786  city_103                   0.920   Male
# ...            ...       ...                     ...    ...
# 18738         1477  city_162                   0.767   Male
# 18800        18365  city_103                   0.920   Male
# 18807          229  city_114                   0.926   Male
# 18944         2678  city_104                   0.924    NaN
# 19044        14441   city_89                   0.925   Male
#
#            relevent_experience enrolled_university education_level  \
# 37     Has relevent experience       no_enrollment             Phd
# 121    Has relevent experience       no_enrollment             Phd
# 130     No relevent experience       no_enrollment             Phd
# 135     No relevent experience       no_enrollment             Phd
# 152     No relevent experience       no_enrollment             Phd
# ...                        ...                 ...             ...
# 18738  Has relevent experience       no_enrollment             Phd
# 18800  Has relevent experience       no_enrollment             Phd
# 18807   No relevent experience       no_enrollment             Phd
# 18944   No relevent experience       no_enrollment             Phd
# 19044  Has relevent experience       no_enrollment             Phd
#
#       major_discipline experience company_size  ... last_new_job  \
# 37                STEM        >20      100-500  ...            4
# 121               STEM        >20      100-500  ...            2
# 130               STEM        >20    1000-4999  ...           >4
# 135               STEM        NaN          NaN  ...          NaN
# 152               STEM        >20        50-99  ...           >4
# ...                ...        ...          ...  ...          ...
# 18738             STEM        >20       10000+  ...            1
# 18800             STEM         15        50-99  ...            4
# 18807             STEM         14    5000-9999  ...           >4
# 18944             STEM        >20        50-99  ...          NaN
# 19044             STEM          6        50-99  ...            2
#
#       training_hours  target  new_call  new_call2  \
# 37                42     1.0         1   0.308667
# 121               20     1.0         1   0.303333
# 130                4     0.0         1   0.297667
# 135               70     0.0         1   0.306667
# 152               14     0.0         1   0.306667
# ...              ...     ...       ...        ...
# 18738             34     0.0         1   0.255667
# 18800            108     0.0         1   0.306667
# 18807              9     1.0         1   0.308667
# 18944             27     0.0         1   0.308000
# 19044            105     0.0         1   0.308333
#
#        city_development_index_group city_development_index_group_q  \
# 37                   (0.849, 0.949]                  (0.92, 0.949]
# 121                  (0.849, 0.949]                  (0.878, 0.92]
# 130                  (0.849, 0.949]                  (0.878, 0.92]
# 135                  (0.849, 0.949]                  (0.878, 0.92]
# 152                  (0.849, 0.949]                  (0.878, 0.92]
# ...                             ...                            ...
# 18738                (0.749, 0.849]                 (0.691, 0.878]
# 18800                (0.849, 0.949]                  (0.878, 0.92]
# 18807                (0.849, 0.949]                  (0.92, 0.949]
# 18944                (0.849, 0.949]                  (0.92, 0.949]
# 19044                (0.849, 0.949]                  (0.92, 0.949]
#
#       city_development_index_group_custom new_education_level  \
# 37                             (0.5, inf]     Masters_and_Phd
# 121                            (0.5, inf]     Masters_and_Phd
# 130                            (0.5, inf]     Masters_and_Phd
# 135                            (0.5, inf]     Masters_and_Phd
# 152                            (0.5, inf]     Masters_and_Phd
# ...                                   ...                 ...
# 18738                          (0.5, inf]     Masters_and_Phd
# 18800                          (0.5, inf]     Masters_and_Phd
# 18807                          (0.5, inf]     Masters_and_Phd
# 18944                          (0.5, inf]     Masters_and_Phd
# 19044                          (0.5, inf]     Masters_and_Phd
#
#       new_training_hours
# 37                  1042
# 121                 1020
# 130                 1004
# 135                 1070
# 152                 1014
# ...                  ...
# 18738               1034
# 18800               1108
# 18807               1009
# 18944               1027
# 19044               1105
#
# [414 rows x 21 columns]

# %% [markdown]
# # Pivot table

# %%
df.groupby('new_education_level', dropna=False)['target'].agg(['count','mean'])
# Out:
#                      count      mean
# new_education_level
# Graduate             11598  0.279790
# Masters_and_Phd       4775  0.207958
# School                2325  0.187097
# NaN                    460  0.226087

# %%
df['new_education_level'] = df['new_education_level'].fillna('no_info')

# %%
t = df.pivot_table(index='new_education_level', values='target', aggfunc=['count', 'mean'])

# %%
t.reset_index()
# Out:
#   new_education_level  count      mean
#                       target    target
# 0            Graduate  11598  0.279790
# 1     Masters_and_Phd   4775  0.207958
# 2              School   2325  0.187097
# 3             no_info    460  0.226087

# %%
t.columns = ['_'.join(col).strip() for col in t.columns.values]

# %%
t
# Out:
#                      count_target  mean_target
# new_education_level
# Graduate                    11598     0.279790
# Masters_and_Phd              4775     0.207958
# School                       2325     0.187097
# no_info                       460     0.226087

# %%
t.reset_index()
# Out:
#   new_education_level  count_target  mean_target
# 0            Graduate         11598     0.279790
# 1     Masters_and_Phd          4775     0.207958
# 2              School          2325     0.187097
# 3             no_info           460     0.226087

# %%
df.pivot_table(index='new_education_level', columns='gender',values='target', aggfunc=['count', 'mean'])
# Out:
#                      count                  mean
# gender              Female  Male Other    Female      Male     Other
# new_education_level
# Graduate               773  8144   112  0.279431  0.257122  0.330357
# Masters_and_Phd        386  3237    31  0.233161  0.186284  0.096774
# School                  71  1598    39  0.267606  0.171464  0.205128
# no_info                  8   242     9  0.125000  0.169421  0.222222

# %%
df.groupby(['new_education_level', 'gender'], dropna=False)['target'].agg(['count','mean'])
# Out:
#                             count      mean
# new_education_level gender
# Graduate            Female    773  0.279431
#                     Male     8144  0.257122
#                     Other     112  0.330357
#                     NaN      2569  0.349552
# Masters_and_Phd     Female    386  0.233161
#                     Male     3237  0.186284
#                     Other      31  0.096774
#                     NaN      1121  0.264942
# School              Female     71  0.267606
#                     Male     1598  0.171464
#                     Other      39  0.205128
#                     NaN       617  0.217180
# no_info             Female      8  0.125000
#                     Male      242  0.169421
#                     Other       9  0.222222
#                     NaN       201  0.298507

# %%
t = (df.groupby('new_education_level', dropna=False)
 [['target', 'city_development_index']]
      .agg(['count','mean']).reset_index())

# %%
t
# Out:
#   new_education_level target           city_development_index
#                        count      mean                  count      mean
# 0            Graduate  11598  0.279790                  11598  0.823731
# 1     Masters_and_Phd   4775  0.207958                   4775  0.840032
# 2              School   2325  0.187097                   2325  0.836080
# 3             no_info    460  0.226087                    460  0.805207

# %%
t.columns = ['_'.join(col).strip() for col in t.columns.values]

# %%
t
# Out:
#   new_education_level_  target_count  target_mean  \
# 0             Graduate         11598     0.279790
# 1      Masters_and_Phd          4775     0.207958
# 2               School          2325     0.187097
# 3              no_info           460     0.226087
#
#    city_development_index_count  city_development_index_mean
# 0                         11598                     0.823731
# 1                          4775                     0.840032
# 2                          2325                     0.836080
# 3                           460                     0.805207

# %% [markdown]
# # Heatmap

# %%
df['gender'] = df['gender'].fillna('no_info')

# %%
t = df.pivot_table(index='new_education_level', columns='gender',values='target', aggfunc=['mean'])

# %%
t
# Out:
#                          mean
# gender                 Female      Male     Other   no_info
# new_education_level
# Graduate             0.279431  0.257122  0.330357  0.349552
# Masters_and_Phd      0.233161  0.186284  0.096774  0.264942
# School               0.267606  0.171464  0.205128  0.217180
# no_info              0.125000  0.169421  0.222222  0.298507

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.1.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
sns.heatmap(t)
# Out:
# <Axes: xlabel='None-gender', ylabel='new_education_level'>

# %%
df.pivot_table(index='new_education_level', columns='gender',values='target', aggfunc=['count'])
# Out:
#                      count
# gender              Female  Male Other no_info
# new_education_level
# Graduate               773  8144   112    2569
# Masters_and_Phd        386  3237    31    1121
# School                  71  1598    39     617
# no_info                  8   242     9     201

# %% [markdown]
# # Корреляция и phik

# %%
df.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours', 'target', 'new_call', 'new_call2',
#        'city_development_index_group', 'city_development_index_group_q',
#        'city_development_index_group_custom', 'new_education_level',
#        'new_training_hours'],
#       dtype='object')

# %%
sns.heatmap(df[['city_development_index', 'training_hours', 'target']].corr(numeric_only = True))
# Out:
# <Axes: >

# %%
! pip install phik
# Out:
# Requirement already satisfied: phik in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (0.12.4)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from phik) (2.1.2)
# Requirement already satisfied: scipy>=1.5.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from phik) (1.14.1)
# Requirement already satisfied: pandas>=0.25.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from phik) (2.2.3)
# Requirement already satisfied: matplotlib>=2.2.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from phik) (3.9.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from phik) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.2.3->phik) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.2.3->phik) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.2.3->phik) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.2.3->phik) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib>=2.2.3->phik) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.2.3->phik) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=2.2.3->phik) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib>=2.2.3->phik) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25.1->phik) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25.1->phik) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->phik) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import phik
from phik.report import plot_correlation_matrix
from phik import report

# %%
phik_overview = df.phik_matrix()
# Out:
# interval columns not set, guessing: ['enrollee_id', 'city_development_index', 'training_hours', 'target', 'new_call', 'new_call2', 'new_training_hours']
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\phik\data_quality.py:72: UserWarning: Not enough unique value for variable new_call for analysis 1. Dropping this column
#   warnings.warn(

# %%
sns.heatmap(phik_overview)
# Out:
# <Axes: >

# %%
phik_overview['target'].sort_values(ascending=False)
# Out:
# target                                 1.000000
# city_development_index_group_q         0.523691
# city_development_index                 0.482287
# new_call2                              0.482287
# city                                   0.477283
# city_development_index_group           0.302403
# experience                             0.238725
# relevent_experience                    0.199859
# new_education_level                    0.132478
# gender                                 0.116653
# last_new_job                           0.114708
# enrolled_university                    0.093803
# education_level                        0.075999
# company_size                           0.071953
# enrollee_id                            0.067472
# company_type                           0.066792
# city_development_index_group_custom    0.066180
# new_training_hours                     0.054314
# major_discipline                       0.029200
# training_hours                         0.026849
# Name: target, dtype: float64

# %% [markdown]
# # Проверяем есть ли связь

# %%
df['city_development_index_group_q']
# Out:
# 0         (0.878, 0.92]
# 1        (0.691, 0.878]
# 2        (0.447, 0.691]
# 3        (0.691, 0.878]
# 4        (0.691, 0.878]
#               ...
# 19153    (0.691, 0.878]
# 19154     (0.878, 0.92]
# 19155     (0.878, 0.92]
# 19156    (0.691, 0.878]
# 19157    (0.691, 0.878]
# Name: city_development_index_group_q, Length: 19158, dtype: category
# Categories (4, interval[float64, right]): [(0.447, 0.691] < (0.691, 0.878] < (0.878, 0.92] < (0.92, 0.949]]

# %%
df.groupby('city_development_index_group_q')['target'].agg(['count', 'mean'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_34732\2482842003.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('city_development_index_group_q')['target'].agg(['count', 'mean'])
#                                 count      mean
# city_development_index_group_q
# (0.447, 0.691]                   3869  0.550530
# (0.691, 0.878]                   3827  0.206428
# (0.878, 0.92]                    8925  0.178375
# (0.92, 0.949]                    2537  0.104454

# %%
t = df.groupby('city')['target'].agg(['count', 'mean'])

# %%
t.sort_values('count', ascending=False).head(10)['mean']
# Out:
# city
# city_103    0.213088
# city_21     0.591044
# city_16     0.116765
# city_114    0.099551
# city_160    0.235503
# city_136    0.104096
# city_67     0.132251
# city_75     0.101639
# city_102    0.171053
# city_104    0.093023
# Name: mean, dtype: float64

# %%
t.sort_values('count', ascending=False).head(10)['mean'].plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
t = df.groupby('city')[['target', 'city_development_index']].agg(['count', 'mean'])

# %%
t.columns = ['_'.join(col).strip() for col in t.columns.values]

# %%
t
# Out:
#           target_count  target_mean  city_development_index_count  \
# city
# city_1              26     0.115385                            26
# city_10             86     0.104651                            86
# city_100           275     0.236364                           275
# city_101            75     0.573333                            75
# city_102           304     0.171053                           304
# ...                ...          ...                           ...
# city_93             26     0.192308                            26
# city_94             26     0.384615                            26
# city_97            104     0.076923                           104
# city_98             79     0.101266                            79
# city_99             94     0.159574                            94
#
#           city_development_index_mean
# city
# city_1                          0.847
# city_10                         0.895
# city_100                        0.887
# city_101                        0.558
# city_102                        0.804
# ...                               ...
# city_93                         0.865
# city_94                         0.698
# city_97                         0.925
# city_98                         0.949
# city_99                         0.915
#
# [123 rows x 4 columns]

# %%
t.sort_values('target_count', ascending=False).head(10)
# Out:
#           target_count  target_mean  city_development_index_count  \
# city
# city_103          4355     0.213088                          4355
# city_21           2702     0.591044                          2702
# city_16           1533     0.116765                          1533
# city_114          1336     0.099551                          1336
# city_160           845     0.235503                           845
# city_136           586     0.104096                           586
# city_67            431     0.132251                           431
# city_75            305     0.101639                           305
# city_102           304     0.171053                           304
# city_104           301     0.093023                           301
#
#           city_development_index_mean
# city
# city_103                        0.920
# city_21                         0.624
# city_16                         0.910
# city_114                        0.926
# city_160                        0.920
# city_136                        0.897
# city_67                         0.855
# city_75                         0.939
# city_102                        0.804
# city_104                        0.924

# %%
df['experience_int'] = df['experience'].replace('<1','0').replace('>20','999').fillna(-1).astype(int)

# %%
df['experience_group'] = pd.qcut(df['experience_int'],5)

# %%
df.groupby('experience_group')['target'].agg(['count','mean'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2404\775867775.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('experience_group')['target'].agg(['count','mean'])
#                   count      mean
# experience_group
# (-1.001, 4.0]      5020  0.358964
# (4.0, 6.0]         2646  0.285336
# (6.0, 11.0]        4459  0.239740
# (11.0, 18.0]       3295  0.170561
# (18.0, 999.0]      3738  0.157571

# %%
df.groupby('experience_group')['target'].mean().plot(kind='bar')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2404\1787338124.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('experience_group')['target'].mean().plot(kind='bar')
# <Axes: xlabel='experience_group'>

# %% [markdown]
# # Игрушечные данные

# %%
t = pd.DataFrame({'col1':[1,2,3,float('nan')],
                  'col2':['a','b','c','d'],
                  'col3':[0]*3 + [1]*1,
                  'col4':[0,0,0,1]})

# %%
t
# Out:
#    col1 col2  col3  col4
# 0   1.0    a     0     0
# 1   2.0    b     0     0
# 2   3.0    c     0     0
# 3   NaN    d     1     1

# %% [markdown]
# # Функции агрегации

# %%
t = pd.DataFrame({'col1':[1,2,3,float('nan')]})

# %%
t
# Out:
#    col1
# 0   1.0
# 1   2.0
# 2   3.0
# 3   NaN

# %%
t['col1'].sum()
# Out:
# np.float64(6.0)

# %%
t['col1'].mean()
# Out:
# np.float64(2.0)

# %%
t['col1'].count()
# Out:
# np.int64(3)

# %%
len(t)
# Out:
# 4

# %% [markdown]
# # Визуализация данных

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
df['gender'].value_counts()
# Out:
# gender
# Male       13221
# no_info     4508
# Female      1238
# Other        191
# Name: count, dtype: int64

# %%
df['gender'].hist()
# Out:
# <Axes: >

# %%
df['gender'] = df['gender'].replace('no_info',float('nan'))

# %%
df['gender'].hist()
# Out:
# <Axes: >

# %%
df['gender'].value_counts(dropna=False).plot(kind='bar')
# Out:
# <Axes: xlabel='gender'>

# %% [markdown]
# # Скаттер

# %%
t = pd.DataFrame({'x':[1,2,3],'y':[1,3,2]})

# %%
t.plot(x='x',y='y',kind='scatter')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size  ... target new_call  \
# 0                 STEM        >20          NaN  ...    1.0        1
# 1                 STEM         15        50-99  ...    0.0        1
# 2                 STEM          5          NaN  ...    0.0        1
# 3      Business Degree         <1          NaN  ...    1.0        1
# 4                 STEM        >20        50-99  ...    0.0        1
# ...                ...        ...          ...  ...    ...      ...
# 19153       Humanities         14          NaN  ...    1.0        1
# 19154             STEM         14          NaN  ...    1.0        1
# 19155             STEM        >20        50-99  ...    0.0        1
# 19156              NaN         <1      500-999  ...    0.0        1
# 19157              NaN          2          NaN  ...    0.0        1
#
#        new_call2  city_development_index_group  \
# 0       0.306667                (0.849, 0.949]
# 1       0.258667                (0.749, 0.849]
# 2       0.208000                (0.548, 0.648]
# 3       0.263000                (0.749, 0.849]
# 4       0.255667                (0.749, 0.849]
# ...          ...                           ...
# 19153   0.292667                (0.849, 0.949]
# 19154   0.306667                (0.849, 0.949]
# 19155   0.306667                (0.849, 0.949]
# 19156   0.267333                (0.749, 0.849]
# 19157   0.285000                (0.849, 0.949]
#
#        city_development_index_group_q  city_development_index_group_custom  \
# 0                       (0.878, 0.92]                           (0.5, inf]
# 1                      (0.691, 0.878]                           (0.5, inf]
# 2                      (0.447, 0.691]                           (0.5, inf]
# 3                      (0.691, 0.878]                           (0.5, inf]
# 4                      (0.691, 0.878]                           (0.5, inf]
# ...                               ...                                  ...
# 19153                  (0.691, 0.878]                           (0.5, inf]
# 19154                   (0.878, 0.92]                           (0.5, inf]
# 19155                   (0.878, 0.92]                           (0.5, inf]
# 19156                  (0.691, 0.878]                           (0.5, inf]
# 19157                  (0.691, 0.878]                           (0.5, inf]
#
#       new_education_level new_training_hours experience_int experience_group
# 0                Graduate                 36            999    (18.0, 999.0]
# 1                Graduate                 47             15     (11.0, 18.0]
# 2                Graduate                 83              5       (4.0, 6.0]
# 3                Graduate                 52              0    (-1.001, 4.0]
# 4         Masters_and_Phd                  8            999    (18.0, 999.0]
# ...                   ...                ...            ...              ...
# 19153            Graduate                 42             14     (11.0, 18.0]
# 19154            Graduate                 52             14     (11.0, 18.0]
# 19155            Graduate                 44            999    (18.0, 999.0]
# 19156              School                 97              0    (-1.001, 4.0]
# 19157              School                127              2    (-1.001, 4.0]
#
# [19158 rows x 23 columns]

# %%
df[df['experience_int'] < 999].plot(x='city_development_index',y='experience_int',kind='scatter',alpha=0.01)
# Out:
# <Axes: xlabel='city_development_index', ylabel='experience_int'>

# %%
(df[df['experience_int'] < 999]
 .groupby('city_development_index_group_q')
 ['experience_int'].agg(['count','mean','median']))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2404\1132550627.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby('city_development_index_group_q')
#                                 count      mean  median
# city_development_index_group_q
# (0.447, 0.691]                   3768  5.603238     5.0
# (0.691, 0.878]                   3408  7.936620     7.0
# (0.878, 0.92]                    6733  8.576860     8.0
# (0.92, 0.949]                    1963  9.099338     9.0

# %%
(df[df['experience_int'] < 999]
 .groupby('city_development_index_group_q')
 ['experience_int'].mean()).plot(ylim=0)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2404\2466754532.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby('city_development_index_group_q')
# <Axes: xlabel='city_development_index_group_q'>

# %% [markdown]
# # Джойны

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size  ... target new_call  \
# 0                 STEM        >20          NaN  ...    1.0        1
# 1                 STEM         15        50-99  ...    0.0        1
# 2                 STEM          5          NaN  ...    0.0        1
# 3      Business Degree         <1          NaN  ...    1.0        1
# 4                 STEM        >20        50-99  ...    0.0        1
# ...                ...        ...          ...  ...    ...      ...
# 19153       Humanities         14          NaN  ...    1.0        1
# 19154             STEM         14          NaN  ...    1.0        1
# 19155             STEM        >20        50-99  ...    0.0        1
# 19156              NaN         <1      500-999  ...    0.0        1
# 19157              NaN          2          NaN  ...    0.0        1
#
#        new_call2  city_development_index_group  \
# 0       0.306667                (0.849, 0.949]
# 1       0.258667                (0.749, 0.849]
# 2       0.208000                (0.548, 0.648]
# 3       0.263000                (0.749, 0.849]
# 4       0.255667                (0.749, 0.849]
# ...          ...                           ...
# 19153   0.292667                (0.849, 0.949]
# 19154   0.306667                (0.849, 0.949]
# 19155   0.306667                (0.849, 0.949]
# 19156   0.267333                (0.749, 0.849]
# 19157   0.285000                (0.849, 0.949]
#
#        city_development_index_group_q  city_development_index_group_custom  \
# 0                       (0.878, 0.92]                           (0.5, inf]
# 1                      (0.691, 0.878]                           (0.5, inf]
# 2                      (0.447, 0.691]                           (0.5, inf]
# 3                      (0.691, 0.878]                           (0.5, inf]
# 4                      (0.691, 0.878]                           (0.5, inf]
# ...                               ...                                  ...
# 19153                  (0.691, 0.878]                           (0.5, inf]
# 19154                   (0.878, 0.92]                           (0.5, inf]
# 19155                   (0.878, 0.92]                           (0.5, inf]
# 19156                  (0.691, 0.878]                           (0.5, inf]
# 19157                  (0.691, 0.878]                           (0.5, inf]
#
#       new_education_level new_training_hours experience_int experience_group
# 0                Graduate                 36            999    (18.0, 999.0]
# 1                Graduate                 47             15     (11.0, 18.0]
# 2                Graduate                 83              5       (4.0, 6.0]
# 3                Graduate                 52              0    (-1.001, 4.0]
# 4         Masters_and_Phd                  8            999    (18.0, 999.0]
# ...                   ...                ...            ...              ...
# 19153            Graduate                 42             14     (11.0, 18.0]
# 19154            Graduate                 52             14     (11.0, 18.0]
# 19155            Graduate                 44            999    (18.0, 999.0]
# 19156              School                 97              0    (-1.001, 4.0]
# 19157              School                127              2    (-1.001, 4.0]
#
# [19158 rows x 23 columns]

# %%
age = df[['enrollee_id']].copy()

# %%
age['age'] = 30

# %%
age
# Out:
#        enrollee_id  age
# 0             8949   30
# 1            29725   30
# 2            11561   30
# 3            33241   30
# 4              666   30
# ...            ...  ...
# 19153         7386   30
# 19154        31398   30
# 19155        24576   30
# 19156         5756   30
# 19157        23834   30
#
# [19158 rows x 2 columns]

# %%
df = df.merge(age,how='left',on='enrollee_id')

# %%
len(df)
# Out:
# 19158

# %%
len(age)
# Out:
# 19158

# %%
len(age['enrollee_id'].drop_duplicates())
# Out:
# 19158

# %%
df.set_index('enrollee_id')
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
#             enrolled_university education_level major_discipline experience  \
# enrollee_id
# 8949              no_enrollment        Graduate             STEM        >20
# 29725             no_enrollment        Graduate             STEM         15
# 11561          Full time course        Graduate             STEM          5
# 33241                       NaN        Graduate  Business Degree         <1
# 666               no_enrollment         Masters             STEM        >20
# ...                         ...             ...              ...        ...
# 7386              no_enrollment        Graduate       Humanities         14
# 31398             no_enrollment        Graduate             STEM         14
# 24576             no_enrollment        Graduate             STEM        >20
# 5756              no_enrollment     High School              NaN         <1
# 23834             no_enrollment  Primary School              NaN          2
#
#             company_size    company_type  ... new_call  new_call2  \
# enrollee_id                               ...
# 8949                 NaN             NaN  ...        1   0.306667
# 29725              50-99         Pvt Ltd  ...        1   0.258667
# 11561                NaN             NaN  ...        1   0.208000
# 33241                NaN         Pvt Ltd  ...        1   0.263000
# 666                50-99  Funded Startup  ...        1   0.255667
# ...                  ...             ...  ...      ...        ...
# 7386                 NaN             NaN  ...        1   0.292667
# 31398                NaN             NaN  ...        1   0.306667
# 24576              50-99         Pvt Ltd  ...        1   0.306667
# 5756             500-999         Pvt Ltd  ...        1   0.267333
# 23834                NaN             NaN  ...        1   0.285000
#
#              city_development_index_group  city_development_index_group_q  \
# enrollee_id
# 8949                       (0.849, 0.949]                   (0.878, 0.92]
# 29725                      (0.749, 0.849]                  (0.691, 0.878]
# 11561                      (0.548, 0.648]                  (0.447, 0.691]
# 33241                      (0.749, 0.849]                  (0.691, 0.878]
# 666                        (0.749, 0.849]                  (0.691, 0.878]
# ...                                   ...                             ...
# 7386                       (0.849, 0.949]                  (0.691, 0.878]
# 31398                      (0.849, 0.949]                   (0.878, 0.92]
# 24576                      (0.849, 0.949]                   (0.878, 0.92]
# 5756                       (0.749, 0.849]                  (0.691, 0.878]
# 23834                      (0.849, 0.949]                  (0.691, 0.878]
#
#              city_development_index_group_custom new_education_level  \
# enrollee_id
# 8949                                  (0.5, inf]            Graduate
# 29725                                 (0.5, inf]            Graduate
# 11561                                 (0.5, inf]            Graduate
# 33241                                 (0.5, inf]            Graduate
# 666                                   (0.5, inf]     Masters_and_Phd
# ...                                          ...                 ...
# 7386                                  (0.5, inf]            Graduate
# 31398                                 (0.5, inf]            Graduate
# 24576                                 (0.5, inf]            Graduate
# 5756                                  (0.5, inf]              School
# 23834                                 (0.5, inf]              School
#
#             new_training_hours experience_int experience_group  age
# enrollee_id
# 8949                        36            999    (18.0, 999.0]   30
# 29725                       47             15     (11.0, 18.0]   30
# 11561                       83              5       (4.0, 6.0]   30
# 33241                       52              0    (-1.001, 4.0]   30
# 666                          8            999    (18.0, 999.0]   30
# ...                        ...            ...              ...  ...
# 7386                        42             14     (11.0, 18.0]   30
# 31398                       52             14     (11.0, 18.0]   30
# 24576                       44            999    (18.0, 999.0]   30
# 5756                        97              0    (-1.001, 4.0]   30
# 23834                      127              2    (-1.001, 4.0]   30
#
# [19158 rows x 23 columns]

# %%
age.groupby('enrollee_id')['age'].min()
# Out:
# enrollee_id
# 1        30
# 2        30
# 4        30
# 5        30
# 7        30
#          ..
# 33375    30
# 33376    30
# 33377    30
# 33379    30
# 33380    30
# Name: age, Length: 19158, dtype: int64

# %% [markdown]
# # Numpy

# %%
sum([1,2,3,4,5])
# Out:
# 15

# %%
np.mean([1,2,3,4,5])
# Out:
# np.float64(3.0)

# %%
np.random.normal()
# Out:
# 1.9595672086728086

# %%
list(range(-10,10,0.5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 list(range(-10,10,0.5))
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
np.random.uniform(size=10) / 100
# Out:
# array([3.39848006e-04, 2.33789660e-03, 7.85572368e-03, 3.98141832e-05,
#        3.56787346e-03, 4.05909523e-03, 4.12818559e-03, 4.68518707e-04,
#        1.79366748e-03, 3.70140740e-03])

# %%
a = [1,2,3]
b = [2,2,2]

# %%
a + b
# Out:
# [1, 2, 3, 2, 2, 2]

# %%
a = np.array([1,2,3])
b = np.array([2,2,2])

# %%
a + b
# Out:
# array([3, 4, 5])

# %%
a * b
# Out:
# array([2, 4, 6])

# %%
pd.DataFrame(a)
# Out:
#    0
# 0  1
# 1  2
# 2  3
